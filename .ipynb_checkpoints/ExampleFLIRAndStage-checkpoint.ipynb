# %%
# For some reason this seems to be necessary in anaconda to stop matplotlib crashing
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(1,1))
plt.plot([1,2],[2,4])
plt.show()

# %%
# Now import everything else
import numpy as np
import pylab
import time

# %% [markdown]
# # Camera Object

# %%
# Make a camera object
#from CamFLIR import CamFLIR
from CamHam import CamHam
cam=CamHam()

# %%
#This is how you take a photo
img=cam.Snap(1)

# %%
#and plot it
plt.figure(figsize=(5,5),dpi=200)
pylab.imshow(img[0],clim=(10000,20000))

# %% [markdown]
# # Stage Object

# %%
#Initiate a stage object
from Stage import Stage
stg=Stage()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6960/4174784277.py in <module>
#       1 #Initiate a stage object
# ----> 2 from Stage import Stage
#       3 stg=Stage()
#
# ~\Documents\GitHub\MicroscopeControlSuite\Stage.py in <module>
#       1 from pipython import GCSDevice
# ----> 2 from pipython import pitools
#       3
#       4 class Stage:
#       5
#
# ~\Anaconda3\envs\camera\lib\site-packages\pipython\pitools\__init__.py in <module>
#       3 """Collection of interfaces to PI controllers."""
#       4
# ----> 5 from pipython.pitools.common.gcsbasepitools import GCSRaise, FrozenClass
#       6 # Wildcard import pitools pylint: disable=W0401
#       7 # Redefining built-in 'basestring' pylint: disable=W0622
#
# ~\Anaconda3\envs\camera\lib\site-packages\pipython\pitools\common\gcsbasepitools.py in <module>
#       9 from logging import debug
#      10 from time import sleep, time
# ---> 11 from future.utils import raise_from
#      12
#      13 from pipython.pidevice.common.gcscommands_helpers import isdeviceavailable
#
# ModuleNotFoundError: No module named 'future'

# %%
#Move in X and into focus
stg.MoveToX(0.0)
stg.MoveToZ(3.4)

#Query position
print("Stage at ",stg.X,stg.Y,stg.Z)

# %% [markdown]
# # Scan Example

# %%
def MakeImageSweep(Zs,showthem=True):
    
    # Put the images in this array
    pics=[]
    
    for i in range(0,len(Zs)):
        
        # Move stage
        stg.MoveToZ(Zs[i])
        
        #Snap a pic
        pics.append(cam.Snap(1)[0])
        

    return pics

# %%
Zs=np.linspace(3.4,3.4027,60)
pics=MakeImageSweep(Zs,showthem=True)

# %%
for i in range(0,len(pics)):
    #Optionally display them
    plt.figure(figsize=(5,5))
    plt.imshow(pics[i])
    plt.title(Zs[i])
    plt.clim(50,250)

# %%
Integrals=[sum(sum(p)) for p in pics]
plt.figure(figsize=(5,5),dpi=150)
plt.xlabel("Z pos (mm)")
plt.ylabel("Intensity (arb)")
plt.plot(Zs,Integrals)
